# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Datasets

# %%
df = pd.read_csv(r"C:\Users\gs602\Downloads\train.csv")

# %%
df2 = pd.read_csv(r"C:\Users\gs602\Downloads\test.csv")

# %%
df2.shape
# Out:
# (270000, 20)

# %% [markdown]
# # EDA & CLEANING

# %%
df2.head()
# Out:
#        id Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0  630000      Silt     6.36          26.19            0.59
# 1  630001      Clay     5.87           9.88            1.18
# 2  630002     Sandy     6.22          26.55            0.96
# 3  630003      Clay     7.68          53.58            0.83
# 4  630004     Loamy     5.23          59.02            0.54
#
#    Electrical_Conductivity  Temperature_C  Humidity  Rainfall_mm  \
# 0                     2.81          17.83     30.24      1533.38
# 1                     3.26          21.18     78.07       576.05
# 2                     0.85          26.87     60.35       545.30
# 3                     0.55          41.74     36.05      1211.03
# 4                     2.11          41.08     52.47      1321.91
#
#    Sunlight_Hours  Wind_Speed_kmh Crop_Type Crop_Growth_Stage  Season  \
# 0            5.40            3.00     Maize            Sowing    Rabi
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270000 entries, 0 to 269999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       270000 non-null  int64
#  1   Soil_Type                270000 non-null  object
#  2   Soil_pH                  270000 non-null  float64
#  3   Soil_Moisture            270000 non-null  float64
#  4   Organic_Carbon           270000 non-null  float64
#  5   Electrical_Conductivity  270000 non-null  float64
#  6   Temperature_C            270000 non-null  float64
#  7   Humidity                 270000 non-null  float64
#  8   Rainfall_mm              270000 non-null  float64
#  9   Sunlight_Hours           270000 non-null  float64
#  10  Wind_Speed_kmh           270000 non-null  float64
#  11  Crop_Type                270000 non-null  object
#  12  Crop_Growth_Stage        270000 non-null  object
# ...

# %%
df2.isnull().sum()
# Out:
# id                         0
# Soil_Type                  0
# Soil_pH                    0
# Soil_Moisture              0
# Organic_Carbon             0
# Electrical_Conductivity    0
# Temperature_C              0
# Humidity                   0
# Rainfall_mm                0
# Sunlight_Hours             0
# Wind_Speed_kmh             0
# Crop_Type                  0
# Crop_Growth_Stage          0
# Season                     0
# Irrigation_Type            0
# Water_Source               0
# Field_Area_hectare         0
# Mulching_Used              0
# Previous_Irrigation_mm     0
# Region                     0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# np.int64(0)

# %%
# df2.drop_duplicates(inplace = True)

# %%
df2.describe()
# Out:
#                   id        Soil_pH  Soil_Moisture  Organic_Carbon  \
# count  270000.000000  270000.000000  270000.000000   270000.000000
# mean   764999.500000       6.480929      37.307614        0.922279
# std     77942.430678       0.922187      16.375273        0.365757
# min    630000.000000       4.800000       8.010000        0.300000
# 25%    697499.750000       5.680000      23.340000        0.610000
# 50%    764999.500000       6.440000      37.770000        0.900000
# 75%    832499.250000       7.260000      51.200000        1.220000
# max    899999.000000       8.200000      64.990000        1.600000
#
#        Electrical_Conductivity  Temperature_C       Humidity    Rainfall_mm  \
# count            270000.000000  270000.000000  270000.000000  270000.000000
# mean                  1.745251      27.001666      61.511319    1464.525885
# std                   0.951329       8.630706      19.690278     612.521709
# ...

# %%
df2.columns
# Out:
# Index(['id', 'Soil_Type', 'Soil_pH', 'Soil_Moisture', 'Organic_Carbon',
#        'Electrical_Conductivity', 'Temperature_C', 'Humidity', 'Rainfall_mm',
#        'Sunlight_Hours', 'Wind_Speed_kmh', 'Crop_Type', 'Crop_Growth_Stage',
#        'Season', 'Irrigation_Type', 'Water_Source', 'Field_Area_hectare',
#        'Mulching_Used', 'Previous_Irrigation_mm', 'Region'],
#       dtype='object')

# %%
sns.countplot(data = df , x = 'Irrigation_Need')
# Out:
# <Axes: xlabel='Irrigation_Need', ylabel='count'>

# %%
plt.figure(figsize=(14, 8)) 
sns.heatmap(df2.corr(numeric_only = True) , annot = True )
# Out:
# <Axes: >

# %% [markdown]
# # Data Preprocessing

# %%
df2.dtypes
# Out:
# id                           int64
# Soil_Type                   object
# Soil_pH                    float64
# Soil_Moisture              float64
# Organic_Carbon             float64
# Electrical_Conductivity    float64
# Temperature_C              float64
# Humidity                   float64
# Rainfall_mm                float64
# Sunlight_Hours             float64
# Wind_Speed_kmh             float64
# Crop_Type                   object
# Crop_Growth_Stage           object
# Season                      object
# Irrigation_Type             object
# Water_Source                object
# Field_Area_hectare         float64
# Mulching_Used               object
# Previous_Irrigation_mm     float64
# Region                      object
# dtype: object

# %%
df2.shape
# Out:
# (270000, 20)

# %%
# ✅ FIXED — fit on train, transform both train and test
from sklearn.preprocessing import LabelEncoder

categorical_cols = df.select_dtypes(include="object").columns.tolist()
# Remove target column if it's still object type here
categorical_cols = [c for c in categorical_cols if c != "Irrigation_Need"]

for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])       # fit+transform on train
    df2[col] = le.transform(df2[col])         # transform test with same encoder

# %%
df2
# Out:
#             id  Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0       630000          3     6.36          26.19            0.59
# 1       630001          0     5.87           9.88            1.18
# 2       630002          2     6.22          26.55            0.96
# 3       630003          0     7.68          53.58            0.83
# 4       630004          1     5.23          59.02            0.54
# ...        ...        ...      ...            ...             ...
# 269995  899995          2     5.63          51.90            0.68
# 269996  899996          1     7.84          45.16            0.85
# 269997  899997          1     7.83          11.02            1.56
# 269998  899998          3     7.12          10.18            1.32
# 269999  899999          0     6.61          24.96            1.41
#
#         Electrical_Conductivity  Temperature_C  Humidity  Rainfall_mm  \
# 0                          2.81          17.83     30.24      1533.38
# ...

# %%
df2.dtypes
# Out:
# id                           int64
# Soil_Type                    int64
# Soil_pH                    float64
# Soil_Moisture              float64
# Organic_Carbon             float64
# Electrical_Conductivity    float64
# Temperature_C              float64
# Humidity                   float64
# Rainfall_mm                float64
# Sunlight_Hours             float64
# Wind_Speed_kmh             float64
# Crop_Type                    int64
# Crop_Growth_Stage            int64
# Season                       int64
# Irrigation_Type              int64
# Water_Source                 int64
# Field_Area_hectare         float64
# Mulching_Used                int64
# Previous_Irrigation_mm     float64
# Region                       int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

object_cols = df2.select_dtypes(include="object").columns.tolist()
print("Encoding these columns:", object_cols)

for col in object_cols:
    le = LabelEncoder()
    df2[col] = le.fit_transform(df2[col].astype(str))

# Also encode same cols in df (train)
for col in object_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col].astype(str))

# Encode target separately
# target_le = LabelEncoder()
# df["Irrigation_Need"] = target_le.fit_transform(df["Irrigation_Need"])

print("df2 dtypes after encoding:")
print(df2.dtypes)
# Out:
# Encoding these columns: []
# df2 dtypes after encoding:
# id                           int64
# Soil_Type                    int64
# Soil_pH                    float64
# Soil_Moisture              float64
# Organic_Carbon             float64
# Electrical_Conductivity    float64
# Temperature_C              float64
# Humidity                   float64
# Rainfall_mm                float64
# Sunlight_Hours             float64
# Wind_Speed_kmh             float64
# Crop_Type                    int64
# Crop_Growth_Stage            int64
# Season                       int64
# Irrigation_Type              int64
# Water_Source                 int64
# Field_Area_hectare         float64
# Mulching_Used                int64
# Previous_Irrigation_mm     float64
# Region                       int64
# dtype: object

# %% [markdown]
# # Model Training

# %%
# !pip install lightgbm

# %%
# ---- Target encoding (train only) ----
target_le = LabelEncoder()
df["Irrigation_Need"] = target_le.fit_transform(df["Irrigation_Need"])

X = df.drop("Irrigation_Need", axis=1)
y = df["Irrigation_Need"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
model = LGBMClassifier(
    n_estimators=1000,
    learning_rate=0.02,
    max_depth=8,
    num_leaves=63,
    subsample=0.8,
    colsample_bytree=0.8,
    min_child_weight=3,
    reg_alpha=0.1,
    reg_lambda=1.5,
    random_state=42,
    n_jobs=-1,
    verbose=-1
)

model.fit(X, y)
# Out:
# LGBMClassifier(colsample_bytree=0.8, learning_rate=0.02, max_depth=8,
#                min_child_weight=3, n_estimators=1000, n_jobs=-1, num_leaves=63,
#                random_state=42, reg_alpha=0.1, reg_lambda=1.5, subsample=0.8,
#                verbose=-1)

# %%
print(target_le.classes_)
# Out:
# ['High' 'Low' 'Medium']

# %%
# Run this BEFORE the encoding cell that converts df columns
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Reload original train to get original labels
df_original = pd.read_csv(r"C:\Users\gs602\Downloads\train.csv")

target_le = LabelEncoder()
target_le.fit(df_original["Irrigation_Need"])  # fit on original string labels

print("Classes:", target_le.classes_)  # should show e.g. ['No' 'Yes']

# Now encode df
df["Irrigation_Need"] = target_le.transform(df["Irrigation_Need"].astype(str))
# Out:
# Classes: ['High' 'Low' 'Medium']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:235, in _encode(values, uniques, check_unknown)
#     234 try:
# --> 235     return _map_to_integer(values, uniques)
#     236 except KeyError as e:
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:174, in _map_to_integer(values, uniques)
#     173 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 174 return xp.asarray([table[v] for v in values], device=device(values))
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_encode.py:167, in _nandict.__missing__(self, key)
#     166     return self.nan_value
# --> 167 raise KeyError(key)
#
# KeyError: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
y_pred_val = model.predict(X_test)
from sklearn.metrics import accuracy_score
print("Val accuracy:", accuracy_score(y_test, y_pred_val))

# ---- ACTUAL SUBMISSION: predict on df2 (test.csv) ----
X_submission = df2[X.columns]
print("Test shape before predict:", X_submission.shape)

test_preds_encoded = model.predict(X_submission)

# ---- Decode predictions back to original labels ----
test_preds = target_le.inverse_transform(test_preds_encoded)
print("Sample predictions:", test_preds[:5])  # should show original labels e.g. 'Yes'/'No'

# ---- Build submission file ----
submission = pd.DataFrame({
    "id": df2["id"],
    "Irrigation_Need": test_preds
})

print("Submission shape:", submission.shape)  # must be (270000, 2)
submission.to_csv(r"C:\Users\gs602\Downloads\submission.csv", index=False)
submission.head()
# Out:
# Val accuracy: 0.9866587301587302
# Test shape before predict: (270000, 20)
# Sample predictions: ['Low' 'Low' 'Low' 'Low' 'Low']
# Submission shape: (270000, 2)
#        id Irrigation_Need
# 0  630000             Low
# 1  630001             Low
# 2  630002             Low
# 3  630003             Low
# 4  630004             Low
